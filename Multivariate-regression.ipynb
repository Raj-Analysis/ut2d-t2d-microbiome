# %%
cd "C:\Users\Gwoncheol\Desktop\"
# Out:
# C:\Users\Gwoncheol\Desktop

# %%
import pandas as pd

df = pd.read_csv('data-diabetes.csv')
df.head(1)
# Out:
#       ID            Group  Age Sex        BMI  SBP  DBP  FBS  HbA1C  \
# 0  M_004  Known_Diabetics   63   M  29.366417  143   90  139    8.1
#
#    Cholesterol  ...  Libanicoccus  f_Prevotellaceae_g_uncultured  \
# 0        256.0  ...           0.0                            0.0
#
#    Gastranaerophilales  Parabacteroides  Family_XIII_AD3011_group  \
# 0             0.015701              0.0                  0.000714
#
#    f_Oscillospiraceae_g_UCG_005  Alistipes  f_Ruminococcaceae_g_uncultured  \
# 0                           0.0   0.000357                             0.0
#
#    o_Oscillospirales_g_UCG_010  Monoglobus
# 0                     0.000306    0.002906
#
# [1 rows x 70 columns]

# %%
import statsmodels.formula.api as smf

# Set 'Group' as categorical with 'Control' as reference
df['Group'] = pd.Categorical(df['Group'], categories=['Control', 'Pre_Diabetics', 'Known_Diabetics', 'Unknown_Diabetics'])

# Define the columns that are NOT outcome variables (predictors/identifiers)
non_outcome_cols = ['ID', 'Group', 'Age', 'Sex', 'BMI']

# Define the base formula for the predictors (the adjustment/confounding factors)
base_predictors = 'C(Group, Treatment(reference="Control")) + Age + BMI + Sex'

# 2. Identify the outcome columns
outcome_cols = [col for col in df.columns if col not in non_outcome_cols]

# Dictionary to store results for all models
all_results = {}

# Helper function logic to extract key results as a DataFrame
def extract_results(model, outcome_name):
    # Extract the coefficients table (index 1 of the summary tables)
    html_table = model.summary().tables[1].as_html()
    
    # Read the HTML into a pandas DataFrame, setting the first column as the index
    df_table = pd.read_html(html_table, header=0, index_col=0)[0]
    
    # Select only Coefficient and P>|t| columns and rename them
    df_results = df_table[['coef', 'P>|t|']].copy()
    df_results.columns = [f'{outcome_name} Coef', f'{outcome_name} P>|t|']
    
    return df_results

# 3. Iterate and model for all identified outcome columns
print("Starting regression analysis for outcomes:", outcome_cols)

for outcome in outcome_cols:
    # Construct the full formula dynamically
    formula = f'{outcome} ~ {base_predictors}'
    
    # Fit the OLS model
    model = smf.ols(formula, data=df).fit()
    
    # Extract and store the results
    results_df = extract_results(model, outcome)
    all_results[outcome] = results_df

# 4. Consolidate results: Merge all results into a single DataFrame
final_summary_df = None
for outcome, df_results in all_results.items():
    if final_summary_df is None:
        final_summary_df = df_results
    else:
        final_summary_df = final_summary_df.merge(df_results, left_index=True, right_index=True, how='outer')

# Rename the index for clarity
final_summary_df.index.name = 'Predictor'

# 5. Save to CSV
output_filename = 'regression_summary_auto_detected.csv'
final_summary_df.to_csv(output_filename)

print(f"\nAnalysis complete. Results saved to {output_filename}")
print(f"Summary DataFrame created. First 5 rows:\n{final_summary_df.head()}")
# Out:
# Starting regression analysis for outcomes: ['SBP', 'DBP', 'FBS', 'HbA1C', 'Cholesterol', 'Triglyceride', 'Serum_Creatinine', 'Insulin', 'Height', 'Weight', 'Waist', 'Hip', 'Waist_to_Hip_Ratio', 'QUICKI', 'HOMA_IR', 'Lactobacillus', 'Bifidobacterium', 'Collinsella', 'Dorea', 'Faecalibacterium', 'Prevotella', 'Agathobacter', 'Blautia', 'Catenibacterium', 'Streptococcus', '_Eubacterium__hallii_group', 'Dialister', 'Holdemanella', 'Subdoligranulum', 'Ruminococcus', '_Eubacterium__coprostanoligenes_group', 'Coprococcus', 'Olsenella', 'Roseburia', '_Ruminococcus__torques_group', 'RF39', 'Fusicatenibacter', '_Ruminococcus__gauvreauii_group', 'Clostridium_sensu_stricto_1', 'Megasphaera', 'Bacteroides', 'Escherichia_Shigella', 'Romboutsia', 'Alloprevotella', 'Clostridia_UCG_014', 'Christensenellaceae_R_7_group', 'Senegalimassilia', 'Rikenellaceae_RC9_gut_group', 'Muribaculaceae', 'Lachnospiraceae_NK4A136_group', 'Butyricicoccus', 'Mitsuokella', 'f_Oscillospiraceae_g_UCG_002', 'f_Eggerthellaceae_g_uncultured', 'Anaerostipes', 'Libanicoccus', 'f_Prevotellaceae_g_uncultured', 'Gastranaerophilales', 'Parabacteroides', 'Family_XIII_AD3011_group', 'f_Oscillospiraceae_g_UCG_005', 'Alistipes', 'f_Ruminococcaceae_g_uncultured', 'o_Oscillospirales_g_UCG_010', 'Monoglobus']
#
# Analysis complete. Results saved to regression_summary_auto_detected.csv
# Summary DataFrame created. First 5 rows:
#                                                     SBP Coef  SBP P>|t|  \
# Predictor
# Intercept                                           119.9778      0.000
# C(Group, Treatment(reference="Control"))[T.Pre_...   -2.6478      0.657
# C(Group, Treatment(reference="Control"))[T.Know...    3.3043      0.574
# C(Group, Treatment(reference="Control"))[T.Unkn...    8.2977      0.211
# Sex[T.M]                                              1.5499      0.685
#
#                                                     DBP Coef  DBP P>|t|  \
# Predictor
# Intercept                                            78.8364      0.000
# C(Group, Treatment(reference="Control"))[T.Pre_...    0.6354      0.864
# C(Group, Treatment(reference="Control"))[T.Know...    1.5526      0.672
# C(Group, Treatment(reference="Control"))[T.Unkn...    5.3232      0.198
# Sex[T.M]                                              7.8348      0.001
#
#                                                     FBS Coef  FBS P>|t|  \
# Predictor
# Intercept                                           122.7426      0.002
# C(Group, Treatment(reference="Control"))[T.Pre_...    5.0200      0.759
# C(Group, Treatment(reference="Control"))[T.Know...   77.0997      0.000
# C(Group, Treatment(reference="Control"))[T.Unkn...   52.5451      0.005
# Sex[T.M]                                              5.5530      0.596
#
#                                                     HbA1C Coef  HbA1C P>|t|  \
# Predictor
# Intercept                                               5.5782        0.000
# C(Group, Treatment(reference="Control"))[T.Pre_...      0.5933        0.294
# C(Group, Treatment(reference="Control"))[T.Know...      3.1021        0.000
# C(Group, Treatment(reference="Control"))[T.Unkn...      2.6335        0.000
# Sex[T.M]                                               -0.0004        0.999
#
#                                                     Cholesterol Coef  \
# Predictor
# Intercept                                                    75.4513
# C(Group, Treatment(reference="Control"))[T.Pre_...           17.0491
# C(Group, Treatment(reference="Control"))[T.Know...           12.1497
# C(Group, Treatment(reference="Control"))[T.Unkn...            9.2603
# Sex[T.M]                                                    -10.9651
#
#                                                     Cholesterol P>|t|  ...  \
# Predictor                                                              ...
# Intercept                                                       0.078  ...
# C(Group, Treatment(reference="Control"))[T.Pre_...              0.350  ...
# C(Group, Treatment(reference="Control"))[T.Know...              0.499  ...
# C(Group, Treatment(reference="Control"))[T.Unkn...              0.646  ...
# Sex[T.M]                                                        0.349  ...
#
#                                                     f_Oscillospiraceae_g_UCG_005 Coef  \
# Predictor
# Intercept                                                                    0.001000
# C(Group, Treatment(reference="Control"))[T.Pre_...                           0.000500
# C(Group, Treatment(reference="Control"))[T.Know...                           0.000029
# C(Group, Treatment(reference="Control"))[T.Unkn...                           0.000300
# Sex[T.M]                                                                    -0.000300
#
#                                                     f_Oscillospiraceae_g_UCG_005 P>|t|  \
# Predictor
# Intercept                                                                        0.404
# C(Group, Treatment(reference="Control"))[T.Pre_...                               0.380
# C(Group, Treatment(reference="Control"))[T.Know...                               0.954
# C(Group, Treatment(reference="Control"))[T.Unkn...                               0.606
# Sex[T.M]                                                                         0.338
#
#                                                     Alistipes Coef  \
# Predictor
# Intercept                                                   0.0019
# C(Group, Treatment(reference="Control"))[T.Pre_...          0.0003
# C(Group, Treatment(reference="Control"))[T.Know...          0.0006
# C(Group, Treatment(reference="Control"))[T.Unkn...          0.0007
# Sex[T.M]                                                   -0.0004
#
#                                                     Alistipes P>|t|  \
# Predictor
# Intercept                                                     0.259
# C(Group, Treatment(reference="Control"))[T.Pre_...            0.688
# C(Group, Treatment(reference="Control"))[T.Know...            0.373
# C(Group, Treatment(reference="Control"))[T.Unkn...            0.396
# Sex[T.M]                                                      0.425
#
#                                                     f_Ruminococcaceae_g_uncultured Coef  \
# Predictor
# Intercept                                                                        0.0033
# C(Group, Treatment(reference="Control"))[T.Pre_...                              -0.0012
# C(Group, Treatment(reference="Control"))[T.Know...                              -0.0009
# C(Group, Treatment(reference="Control"))[T.Unkn...                              -0.0015
# Sex[T.M]                                                                        -0.0009
#
#                                                     f_Ruminococcaceae_g_uncultured P>|t|  \
# Predictor
# Intercept                                                                          0.196
# C(Group, Treatment(reference="Control"))[T.Pre_...                                 0.250
# C(Group, Treatment(reference="Control"))[T.Know...                                 0.415
# C(Group, Treatment(reference="Control"))[T.Unkn...                                 0.226
# Sex[T.M]                                                                           0.219
#
#                                                     o_Oscillospirales_g_UCG_010 Coef  \
# Predictor
# Intercept                                                                     0.0038
# C(Group, Treatment(reference="Control"))[T.Pre_...                           -0.0012
# C(Group, Treatment(reference="Control"))[T.Know...                           -0.0012
# C(Group, Treatment(reference="Control"))[T.Unkn...                           -0.0005
# Sex[T.M]                                                                     -0.0011
#
#                                                     o_Oscillospirales_g_UCG_010 P>|t|  \
# Predictor
# Intercept                                                                       0.032
# C(Group, Treatment(reference="Control"))[T.Pre_...                              0.117
# C(Group, Treatment(reference="Control"))[T.Know...                              0.103
# C(Group, Treatment(reference="Control"))[T.Unkn...                              0.509
# Sex[T.M]                                                                        0.020
#
#                                                     Monoglobus Coef  \
# Predictor
# Intercept                                                    0.0030
# C(Group, Treatment(reference="Control"))[T.Pre_...           0.0003
# C(Group, Treatment(reference="Control"))[T.Know...           0.0006
# C(Group, Treatment(reference="Control"))[T.Unkn...           0.0003
# Sex[T.M]                                                    -0.0013
#
#                                                     Monoglobus P>|t|
# Predictor
# Intercept                                                      0.114
# C(Group, Treatment(reference="Control"))[T.Pre_...             0.759
# C(Group, Treatment(reference="Control"))[T.Know...             0.422
# C(Group, Treatment(reference="Control"))[T.Unkn...             0.763
# Sex[T.M]                                                       0.016
#
# [5 rows x 130 columns]
