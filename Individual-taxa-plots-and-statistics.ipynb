# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.pylab as pylab
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms

# %%
cd C:\Users\Gwoncheol\Dropbox\[Microbiome_analysis]\[Qiime2]\QIIME2_Indian_Diebetes_study\Visualization\Taxa-individual
# Out:
# C:\Users\Gwoncheol\Dropbox\[Microbiome_analysis]\[Qiime2]\QIIME2_Indian_Diebetes_study\Visualization\Taxa-individual

# %%
colors = ["#000001","#000001","#000001"]
sns.set_palette(sns.color_palette(colors))

# %%
df1 = pd.read_csv('Taxa-feature-individual.csv')
df1.head(1)
# Out:
#   #OTU ID Group  Age Sex  SBP  DBP  FBS  HbA1C  Cholesterol  Triglyceride  \
# 0   M_161    Ct   50   F  120   90   79    5.2        169.9         10.56
#
#    ...  \
# 0  ...
#
#    d_Bacteria;p_Firmicutes;c_Bacilli;o_Erysipelotrichales;f_Erysipelatoclostridiaceae;g_UCG-004  \
# 0                                                0.0
#
#    d_Bacteria;p_Proteobacteria;c_Gammaproteobacteria;o_Burkholderiales;f_Oxalobacteraceae;g_Herbaspirillum  \
# 0                                                0.0
#
#    d_Bacteria;p_Proteobacteria;c_Alphaproteobacteria;o_Rickettsiales;f_Mitochondria;g_Mitochondria  \
# 0                                                0.0
#
#    d_Bacteria;p_Actinobacteriota;c_Actinobacteria;o_Micrococcales;f_Micrococcaceae;g_Kocuria  \
# 0                                                0.0
#
#    d_Bacteria;p_Firmicutes;c_Bacilli;o_Staphylococcales;f_Gemellaceae;g_Gemella  \
# 0                                                0.0
#
# ...

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2,3)
# Out:
# <img src="data:image/png;base64,..." width="200">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["FBS-classification"], errcolor="black",
            y=df1["d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Lactobacillaceae;g_Lactobacillus"], 
            palette=colors, width=0.8, linewidth=1.5, errorbar=("se"), capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["FBS-classification"], data=df1, color="white", size=2.5, ax=ax1, edgecolor="black", linewidth=0.7,
#              y=df1["d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Lactobacillaceae;g_Lactobacillus"])

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Abundance", size=13)
ax1.set_title("Lactobacillus",size=15)
ax1.set(ylim=(0, 0.3))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("FBS-Lactobacillus.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2,3)
# Out:
# <img src="data:image/png;base64,..." width="200">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["HbA1C-classification"], errcolor="black",
            y=df1["d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Lactobacillaceae;g_Lactobacillus"], 
            palette=colors, width=0.8, linewidth=1.5, errorbar=("se"), capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["HbA1C-classification"], data=df1, color="white", size=2.5, ax=ax1, edgecolor="black", linewidth=0.7,
#              y=df1["d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Lactobacillaceae;g_Lactobacillus"])

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Abundance", size=13)
ax1.set_title("Lactobacillus",size=15)
ax1.set(ylim=(0, 0.2))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("HbA1C-Lactobacillus.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2,3)
# Out:
# <img src="data:image/png;base64,..." width="200">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["FBS-classification"], errcolor="black",
            y=df1["d_Bacteria;p_Verrucomicrobiota;c_Verrucomicrobiae;o_Verrucomicrobiales;f_Akkermansiaceae;g_Akkermansia"], 
            palette=colors, width=0.8, linewidth=1.5, errorbar=("se"), capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["FBS-classification"], data=df1, color="white", size=2.5, ax=ax1, edgecolor="black", linewidth=0.7,
#              y=df1["d_Bacteria;p_Verrucomicrobiota;c_Verrucomicrobiae;o_Verrucomicrobiales;f_Akkermansiaceae;g_Akkermansia"])

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Abundance", size=13)
ax1.set_title("Akkermansia",size=15)
ax1.set(ylim=(0, 0.025))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("FBS-Akkermansia.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2,3)
# Out:
# <img src="data:image/png;base64,..." width="200">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["HbA1C-classification"], errcolor="black",
            y=df1["d_Bacteria;p_Verrucomicrobiota;c_Verrucomicrobiae;o_Verrucomicrobiales;f_Akkermansiaceae;g_Akkermansia"], 
            palette=colors, width=0.8, linewidth=1.5, errorbar=("se"), capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["HbA1C-classification"], data=df1, color="white", size=2.5, ax=ax1, edgecolor="black", linewidth=0.7,
#              y=df1["d_Bacteria;p_Verrucomicrobiota;c_Verrucomicrobiae;o_Verrucomicrobiales;f_Akkermansiaceae;g_Akkermansia"])

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Abundance", size=13)
ax1.set_title("Akkermansia",size=15)
ax1.set(ylim=(0, 0.06))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("HbA1C-Akkermansia.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2,3)
# Out:
# <img src="data:image/png;base64,..." width="200">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["FBS-classification"], errcolor="black",
            y=df1["d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Streptococcaceae;g_Streptococcus"], 
            palette=colors, width=0.8, linewidth=1.5, errorbar=("se"), capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["FBS-classification"], data=df1, color="white", size=2.5, ax=ax1, edgecolor="black", linewidth=0.7,
#              y=df1["d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Streptococcaceae;g_Streptococcus"])

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Abundance", size=13)
ax1.set_title("Streptococcus",size=15)
ax1.set(ylim=(0, 0.125))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("FBS-Streptococcus.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2,3)
# Out:
# <img src="data:image/png;base64,..." width="200">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["HbA1C-classification"], errcolor="black",
            y=df1["d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Streptococcaceae;g_Streptococcus"], 
            palette=colors, width=0.8, linewidth=1.5, errorbar=("se"), capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["HbA1C-classification"], data=df1, color="white", size=2.5, ax=ax1, edgecolor="black", linewidth=0.7,
#              y=df1["d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Streptococcaceae;g_Streptococcus"])

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Abundance", size=13)
ax1.set_title("Streptococcus",size=15)
ax1.set(ylim=(0, 0.2))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("HbA1C-Streptococcus.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2,3)
# Out:
# <img src="data:image/png;base64,..." width="200">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["FBS-classification"], errcolor="black",
            y=df1["d_Bacteria;p_Bacteroidota;c_Bacteroidia;o_Bacteroidales;_;_"], 
            palette=colors, width=0.8, linewidth=1.5, errorbar=("se"), capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["FBS-classification"], data=df1, color="white", size=2.5, ax=ax1, edgecolor="black", linewidth=0.7,
#              y=df1["d_Bacteria;p_Bacteroidota;c_Bacteroidia;o_Bacteroidales;_;_"])

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Abundance", size=13)
ax1.set_title("o_Bacteroidales;_;_",size=15)
ax1.set(ylim=(0, 0.15))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("FBS-o_Bacteroidales;_;_.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2,3)
# Out:
# <img src="data:image/png;base64,..." width="200">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["HbA1C-classification"], errcolor="black",
            y=df1["d_Bacteria;p_Bacteroidota;c_Bacteroidia;o_Bacteroidales;_;_"], 
            palette=colors, width=0.8, linewidth=1.5, errorbar=("se"), capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["HbA1C-classification"], data=df1, color="white", size=2.5, ax=ax1, edgecolor="black", linewidth=0.7,
#              y=df1["d_Bacteria;p_Bacteroidota;c_Bacteroidia;o_Bacteroidales;_;_"])

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Abundance", size=13)
ax1.set_title("o_Bacteroidales;_;_",size=15)
ax1.set(ylim=(0, 0.15))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("HbA1C-o_Bacteroidales;_;_.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2,3)
# Out:
# <img src="data:image/png;base64,..." width="200">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["FBS-classification"], errcolor="black",
            y=df1["d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Coriobacteriaceae;g_Collinsella"], 
            palette=colors, width=0.8, linewidth=1.5, errorbar=("se"), capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["FBS-classification"], data=df1, color="white", size=2.5, ax=ax1, edgecolor="black", linewidth=0.7,
#              y=df1["d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Coriobacteriaceae;g_Collinsella"])

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Abundance", size=13)
ax1.set_title("Collinsella",size=15)
ax1.set(ylim=(0, 0.025))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("FBS-Collinsella.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2,3)
# Out:
# <img src="data:image/png;base64,..." width="200">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["HbA1C-classification"], errcolor="black",
            y=df1["d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Coriobacteriaceae;g_Collinsella"], 
            palette=colors, width=0.8, linewidth=1.5, errorbar=("se"), capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["HbA1C-classification"], data=df1, color="white", size=2.5, ax=ax1, edgecolor="black", linewidth=0.7,
#              y=df1["d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Coriobacteriaceae;g_Collinsella"])

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Abundance", size=13)
ax1.set_title("Collinsella",size=15)
ax1.set(ylim=(0, 0.025))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("HbA1C-Collinsella.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2,3)
# Out:
# <img src="data:image/png;base64,..." width="200">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["FBS-classification"], errcolor="black",
            y=df1["d_Bacteria;p_Firmicutes;c_Clostridia;o_Clostridiales;f_Clostridiaceae;g_Clostridium_sensu_stricto_1"], 
            palette=colors, width=0.8, linewidth=1.5, errorbar=("se"), capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["FBS-classification"], data=df1, color="white", size=2.5, ax=ax1, edgecolor="black", linewidth=0.7,
#              y=df1["d_Bacteria;p_Firmicutes;c_Clostridia;o_Clostridiales;f_Clostridiaceae;g_Clostridium_sensu_stricto_1"])

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Abundance", size=13)
ax1.set_title("Clostridium_sensu_stricto_1",size=15)
ax1.set(ylim=(0, 0.03))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("FBS-Clostridium_sensu_stricto_1.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2,3)
# Out:
# <img src="data:image/png;base64,..." width="200">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["HbA1C-classification"], errcolor="black",
            y=df1["d_Bacteria;p_Firmicutes;c_Clostridia;o_Clostridiales;f_Clostridiaceae;g_Clostridium_sensu_stricto_1"], 
            palette=colors, width=0.8, linewidth=1.5, errorbar=("se"), capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["HbA1C-classification"], data=df1, color="white", size=2.5, ax=ax1, edgecolor="black", linewidth=0.7,
#              y=df1["d_Bacteria;p_Firmicutes;c_Clostridia;o_Clostridiales;f_Clostridiaceae;g_Clostridium_sensu_stricto_1"])

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Abundance", size=13)
ax1.set_title("Clostridium_sensu_stricto_1",size=15)
ax1.set(ylim=(0, 0.04))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("HbA1C-Clostridium_sensu_stricto_1.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2,3)
# Out:
# <img src="data:image/png;base64,..." width="200">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["FBS-classification"], errcolor="black",
            y=df1["d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Atopobiaceae;g_Olsenella"], 
            palette=colors, width=0.8, linewidth=1.5, errorbar=("se"), capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["FBS-classification"], data=df1, color="white", size=2.5, ax=ax1, edgecolor="black", linewidth=0.7,
#              y=df1["d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Atopobiaceae;g_Olsenella"])

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Abundance", size=13)
ax1.set_title("Olsenella",size=15)
ax1.set(ylim=(0, 0.015))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("FBS-Olsenella.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2,3)
# Out:
# <img src="data:image/png;base64,..." width="200">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["HbA1C-classification"], errcolor="black",
            y=df1["d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Atopobiaceae;g_Olsenella"], 
            palette=colors, width=0.8, linewidth=1.5, errorbar=("se"), capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["HbA1C-classification"], data=df1, color="white", size=2.5, ax=ax1, edgecolor="black", linewidth=0.7,
#              y=df1["d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Atopobiaceae;g_Olsenella"])

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Abundance", size=13)
ax1.set_title("Olsenella",size=15)
ax1.set(ylim=(0, 0.015))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("HbA1C-Olsenella.svg", bbox_inches='tight')

# %% [markdown]
# ## Reg plot

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pylab as pylab

# %%
df1 = pd.read_csv('Taxa-feature-individual.csv')
df1.head(1)
# Out:
#   #OTU ID    Group  Age Sex  SBP  DBP  FBS  HbA1C  Cholesterol  Triglyceride  \
# 0   M_161  Control   50   F  120   90   79    5.2        169.9         10.56
#
#    ...  \
# 0  ...
#
#    d_Bacteria;p_Firmicutes;c_Bacilli;o_Erysipelotrichales;f_Erysipelatoclostridiaceae;g_UCG-004  \
# 0                                                0.0
#
#    d_Bacteria;p_Proteobacteria;c_Gammaproteobacteria;o_Burkholderiales;f_Oxalobacteraceae;g_Herbaspirillum  \
# 0                                                0.0
#
#    d_Bacteria;p_Proteobacteria;c_Alphaproteobacteria;o_Rickettsiales;f_Mitochondria;g_Mitochondria  \
# 0                                                0.0
#
#    d_Bacteria;p_Actinobacteriota;c_Actinobacteria;o_Micrococcales;f_Micrococcaceae;g_Kocuria  \
# 0                                                0.0
#
#    d_Bacteria;p_Firmicutes;c_Bacilli;o_Staphylococcales;f_Gemellaceae;g_Gemella  \
# 0                                                0.0
#
# ...

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.5,2.3)
# Out:
# <img src="data:image/png;base64,..." width="250">

# %%
sns.set(font_scale=1.0)

sns.regplot(x=df1["FBS"], y=df1["d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Lactobacillaceae;g_Lactobacillus"], 
            scatter_kws={'s':10}, color="#3b3838", line_kws={"color":"#bd1c00","alpha":0.7,"lw":2}, ax=ax1)

ax1.set_xlabel("FBS",size=15)
ax1.set_ylabel("Lactobacillus", size=15)
ax1.set_title("",size=20)
#ax1.set(ylim=(5, 60))

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)
plt.savefig("reg-FBS-Lactobacillus.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.5,2.3)
# Out:
# <img src="data:image/png;base64,..." width="250">

# %%
sns.set(font_scale=1.0)

sns.regplot(x=df1["HbA1C"], y=df1["d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Lactobacillaceae;g_Lactobacillus"], 
            scatter_kws={'s':10}, color="#3b3838", line_kws={"color":"#bd1c00","alpha":0.7,"lw":2}, ax=ax1)

ax1.set_xlabel("HbA1C",size=15)
ax1.set_ylabel("Lactobacillus", size=15)
ax1.set_title("",size=20)
#ax1.set(ylim=(5, 60))

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)
plt.savefig("reg-HbA1C-Lactobacillus.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.5,2.3)
# Out:
# <img src="data:image/png;base64,..." width="250">

# %%
sns.set(font_scale=1.0)

sns.regplot(x=df1["FBS"], y=df1["d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Coriobacteriaceae;g_Collinsella"], 
            scatter_kws={'s':10}, color="#3b3838", line_kws={"color":"#bd1c00","alpha":0.7,"lw":2}, ax=ax1)

ax1.set_xlabel("FBS",size=15)
ax1.set_ylabel("Collinsella", size=15)
ax1.set_title("",size=20)
#ax1.set(ylim=(5, 60))

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)
plt.savefig("reg-FBS-Collinsella.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.5,2.3)
# Out:
# <img src="data:image/png;base64,..." width="250">

# %%
sns.set(font_scale=1.0)

sns.regplot(x=df1["FBS"], y=df1["d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Atopobiaceae;g_Olsenella"], 
            scatter_kws={'s':10}, color="#3b3838", line_kws={"color":"#bd1c00","alpha":0.7,"lw":2}, ax=ax1)

ax1.set_xlabel("FBS",size=15)
ax1.set_ylabel("Olsenella", size=15)
ax1.set_title("",size=20)
ax1.set(ylim=(-0.003, 0.06))

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)
plt.savefig("reg-FBS-Olsenella.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.5,2.3)
# Out:
# <img src="data:image/png;base64,..." width="250">

# %%
sns.set(font_scale=1.0)

sns.regplot(x=df1["FBS"], y=df1["d_Bacteria;p_Firmicutes;c_Clostridia;o_Clostridiales;f_Clostridiaceae;g_Clostridium_sensu_stricto_1"], 
            scatter_kws={'s':10}, color="#3b3838", line_kws={"color":"#36a8a3","alpha":0.7,"lw":2}, ax=ax1)

ax1.set_xlabel("FBS",size=15)
ax1.set_ylabel("Clostridium_sensu_stricto_1", size=15)
ax1.set_title("",size=20)
ax1.set(ylim=(-0.007, 0.12))

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)
plt.savefig("reg-FBS-Clostridium_sensu_stricto_1.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.5,2.3)
# Out:
# <img src="data:image/png;base64,..." width="250">

# %%
sns.set(font_scale=1.0)

sns.regplot(x=df1["HbA1C"], y=df1["d_Bacteria;p_Firmicutes;c_Clostridia;o_Clostridiales;f_Clostridiaceae;g_Clostridium_sensu_stricto_1"], 
            scatter_kws={'s':10}, color="#3b3838", line_kws={"color":"#36a8a3","alpha":0.7,"lw":2}, ax=ax1)

ax1.set_xlabel("HbA1C",size=15)
ax1.set_ylabel("Clostridium_sensu_stricto_1", size=15)
ax1.set_title("",size=20)
ax1.set(ylim=(-0.007, 0.12))

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)
plt.savefig("reg-HbA1C-Clostridium_sensu_stricto_1.svg", bbox_inches='tight')

# %% [markdown]
# ## Markers

# %%
colors = ["#545454","#ffaa00","#c90000","#0d6570"]
sns.set_palette(sns.color_palette(colors))

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.3,3)
# Out:
# <img src="data:image/png;base64,..." width="229">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["Group"], y=df1["Age"], palette=colors, width=0.75, linewidth=1.5, errorbar=("se"),
           capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["Group"], y=df1["Age"], data=df1, color="white", size=3, ax=ax1, edgecolor="black", linewidth=1)

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Age", size=13)
ax1.set_title("Age",size=15)
ax1.set(ylim=(10, 60))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("Markers-Age.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.3,3)
# Out:
# <img src="data:image/png;base64,..." width="229">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["Group"], y=df1["SBP"], palette=colors, width=0.75, linewidth=1.5, errorbar=("se"),
           capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["Group"], y=df1["SBP"], data=df1, color="white", size=3, ax=ax1, edgecolor="black", linewidth=1)

ax1.set_xlabel("",size=10)
ax1.set_ylabel("SBP", size=13)
ax1.set_title("SBP",size=15)
ax1.set(ylim=(100, 150))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("Markers-SBP.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.3,3)
# Out:
# <img src="data:image/png;base64,..." width="229">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["Group"], y=df1["DBP"], palette=colors, width=0.75, linewidth=1.5, errorbar=("se"),
           capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["Group"], y=df1["DBP"], data=df1, color="white", size=3, ax=ax1, edgecolor="black", linewidth=1)

ax1.set_xlabel("",size=10)
ax1.set_ylabel("DBP", size=13)
ax1.set_title("DBP",size=15)
ax1.set(ylim=(60,100))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("Markers-DBP.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.3,3)
# Out:
# <img src="data:image/png;base64,..." width="229">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["Group"], y=df1["FBS"], palette=colors, width=0.75, linewidth=1.5, errorbar=("se"),
           capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["Group"], y=df1["FBS"], data=df1, color="white", size=3, ax=ax1, edgecolor="black", linewidth=1)

ax1.set_xlabel("",size=10)
ax1.set_ylabel("FBS", size=13)
ax1.set_title("FBS",size=15)
ax1.set(ylim=(50,200))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("Markers-FBS.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.3,3)
# Out:
# <img src="data:image/png;base64,..." width="229">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["Group"], y=df1["HbA1C"], palette=colors, width=0.75, linewidth=1.5, errorbar=("se"),
           capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["Group"], y=df1["HbA1C"], data=df1, color="white", size=3, ax=ax1, edgecolor="black", linewidth=1)

ax1.set_xlabel("",size=10)
ax1.set_ylabel("HbA1C", size=13)
ax1.set_title("HbA1C",size=15)
ax1.set(ylim=(4,10))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("Markers-HbA1C.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.3,3)
# Out:
# <img src="data:image/png;base64,..." width="229">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["Group"], y=df1["Cholesterol"], palette=colors, width=0.75, linewidth=1.5, errorbar=("se"),
           capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["Group"], y=df1["Cholesterol"], data=df1, color="white", size=3, ax=ax1, edgecolor="black", linewidth=1)

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Cholesterol", size=13)
ax1.set_title("Cholesterol",size=15)
ax1.set(ylim=(100,200))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("Markers-Cholesterol.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.3,3)
# Out:
# <img src="data:image/png;base64,..." width="229">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["Group"], y=df1["Triglyceride"], palette=colors, width=0.75, linewidth=1.5, errorbar=("se"),
           capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["Group"], y=df1["Triglyceride"], data=df1, color="white", size=3, ax=ax1, edgecolor="black", linewidth=1)

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Triglyceride", size=13)
ax1.set_title("Triglyceride",size=15)
ax1.set(ylim=(0,150))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("Markers-Triglyceride.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.3,3)
# Out:
# <img src="data:image/png;base64,..." width="229">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["Group"], y=df1["Serum Creatinine"], palette=colors, width=0.75, linewidth=1.5, errorbar=("se"),
           capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["Group"], y=df1["Serum Creatinine"], data=df1, color="white", size=3, ax=ax1, edgecolor="black", linewidth=1)

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Serum Creatinine", size=13)
ax1.set_title("Serum Creatinine",size=15)
ax1.set(ylim=(0.5,1))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("Markers-Serum Creatinine.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.3,3)
# Out:
# <img src="data:image/png;base64,..." width="229">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["Group"], y=df1["Insulin"], palette=colors, width=0.75, linewidth=1.5, errorbar=("se"),
           capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["Group"], y=df1["Insulin"], data=df1, color="white", size=3, ax=ax1, edgecolor="black", linewidth=1)

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Insulin", size=13)
ax1.set_title("Insulin",size=15)
ax1.set(ylim=(0,14))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("Markers-Insulin.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.3,3)
# Out:
# <img src="data:image/png;base64,..." width="229">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["Group"], y=df1["Weight"], palette=colors, width=0.75, linewidth=1.5, errorbar=("se"),
           capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["Group"], y=df1["Weight"], data=df1, color="white", size=3, ax=ax1, edgecolor="black", linewidth=1)

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Weight", size=13)
ax1.set_title("Weight",size=15)
ax1.set(ylim=(40,80))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("Markers-Weight.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.3,3)
# Out:
# <img src="data:image/png;base64,..." width="229">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["Group"], y=df1["Waist"], palette=colors, width=0.75, linewidth=1.5, errorbar=("se"),
           capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["Group"], y=df1["Weight"], data=df1, color="white", size=3, ax=ax1, edgecolor="black", linewidth=1)

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Waist", size=13)
ax1.set_title("Waist",size=15)
ax1.set(ylim=(70,110))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("Markers-Waist.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.3,3)
# Out:
# <img src="data:image/png;base64,..." width="229">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["Group"], y=df1["Hip"], palette=colors, width=0.75, linewidth=1.5, errorbar=("se"),
           capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["Group"], y=df1["Hip"], data=df1, color="white", size=3, ax=ax1, edgecolor="black", linewidth=1)

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Hip", size=13)
ax1.set_title("Hip",size=15)
ax1.set(ylim=(80,110))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("Markers-Hip.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.3,3)
# Out:
# <img src="data:image/png;base64,..." width="229">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["Group"], y=df1["Body Mass Index"], palette=colors, width=0.75, linewidth=1.5, errorbar=("se"),
           capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["Group"], y=df1["BMI"], data=df1, color="white", size=3, ax=ax1, edgecolor="black", linewidth=1)

ax1.set_xlabel("",size=10)
ax1.set_ylabel("BMI", size=13)
ax1.set_title("BMI",size=15)
ax1.set(ylim=(20,30))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("Markers-BMI.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.3,3)
# Out:
# <img src="data:image/png;base64,..." width="229">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["Group"], y=df1["Waist to Hip Ratio"], palette=colors, width=0.75, linewidth=1.5, errorbar=("se"),
           capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["Group"], y=df1["BMI"], data=df1, color="white", size=3, ax=ax1, edgecolor="black", linewidth=1)

ax1.set_xlabel("",size=10)
ax1.set_ylabel("Waist/Hip ratio", size=13)
ax1.set_title("Waist/Hip ratio",size=15)
ax1.set(ylim=(0.8,1.05))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("Markers-Waist_Hip_ratio.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.3,3)
# Out:
# <img src="data:image/png;base64,..." width="229">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["Group"], y=df1["QUICKI"], palette=colors, width=0.75, linewidth=1.5, errorbar=("se"),
           capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["Group"], y=df1["QUICKI"], data=df1, color="white", size=3, ax=ax1, edgecolor="black", linewidth=1)

ax1.set_xlabel("",size=10)
ax1.set_ylabel("QUICKI", size=13)
ax1.set_title("QUICKI",size=15)
ax1.set(ylim=(0.25,0.45))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("Markers-QUICKI.svg", bbox_inches='tight')

# %%
# %matplotlib nbagg
sns.set_style("white")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
fig.set_size_inches(2.3,3)
# Out:
# <img src="data:image/png;base64,..." width="229">

# %%
sns.set(font_scale=1.2)

sns.barplot(data=df1, x=df1["Group"], y=df1["HOMA-IR"], palette=colors, width=0.75, linewidth=1.5, errorbar=("se"),
           capsize=0.4, edgecolor="Black", errwidth=1.5)

#sns.swarmplot(x=df1["Group"], y=df1["HOMA-IR"], data=df1, color="white", size=3, ax=ax1, edgecolor="black", linewidth=1)

ax1.set_xlabel("",size=10)
ax1.set_ylabel("HOMA-IR", size=13)
ax1.set_title("HOMA-IR",size=15)
ax1.set(ylim=(0,5))
plt.xticks(size=14, rotation=0)
plt.yticks(size=11)

ax1 = plt.gca()
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True, width=2)

plt.savefig("Markers-HOMA-IR.svg", bbox_inches='tight')

# %% [markdown]
# ## Statistical Test

# %%
import pandas as pd
from scipy.stats import f_oneway
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
df1 = pd.read_csv('Taxa-feature-individual.csv')
df1
# Out:
#    #OTU ID Group  Age Sex  SBP  DBP  FBS  HbA1C  Cholesterol  Triglyceride  \
# 0    M_161    Ct   50   F  120   90   79    5.2        169.9         10.56
# 1    M_247    Ct   42   M  119   82   81    5.6        112.4        152.00
# 2    M_237    Ct   54   F  136   82   82    5.5        175.1         38.74
# 3    M_113    Ct   58   F  127   88   82    5.3        196.0         44.91
# 4    M_196    Ct   34   M  199  112   85    5.5        153.1         19.95
# ..     ...   ...  ...  ..  ...  ...  ...    ...          ...           ...
# 90   M_287  UK-D   53   M  120   79   97    7.0        108.8         74.09
# 91   M_195  UK-D   52   F  179   88   99    6.7        189.9         31.08
# 92   M_048  UK-D   40   F  112   69  108    6.6        133.4         36.40
# 93   M_278  UK-D   37   F  133   94  121    7.4        105.9         82.27
# 94   M_282  UK-D   63   M  129   79  125    6.6        175.4         94.97
#
#     ...  \
# 0   ...
# 1   ...
# 2   ...
# 3   ...
# 4   ...
# ...

# %%
#One-way ANOVA
groups = df1['FBS-classification'].unique()
group_data = [df1[df1['FBS-classification'] == group]['d_Bacteria;p_Firmicutes;c_Clostridia;o_Clostridiales;f_Clostridiaceae;g_Clostridium_sensu_stricto_1'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['d_Bacteria;p_Firmicutes;c_Clostridia;o_Clostridiales;f_Clostridiaceae;g_Clostridium_sensu_stricto_1'], df1['FBS-classification'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 1.8309596558181203
# P-Value: 0.16605116005825635
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Db     NL   0.0121 0.1655 -0.0037 0.0279  False
#     Db   P-Db    0.011 0.3953 -0.0091 0.0311  False
#     NL   P-Db  -0.0011 0.9893 -0.0205 0.0182  False
# ---------------------------------------------------

# %%
#One-way ANOVA
groups = df1['HbA1C-classification'].unique()
group_data = [df1[df1['HbA1C-classification'] == group]['d_Bacteria;p_Firmicutes;c_Clostridia;o_Clostridiales;f_Clostridiaceae;g_Clostridium_sensu_stricto_1'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['d_Bacteria;p_Firmicutes;c_Clostridia;o_Clostridiales;f_Clostridiaceae;g_Clostridium_sensu_stricto_1'], df1['HbA1C-classification'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 4.072934593381432
# P-Value: 0.020189250985004188
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Db     NL   0.0073 0.6196 -0.0113 0.0258  False
#     Db   P-Db   0.0191 0.0146  0.0032  0.035   True
#     NL   P-Db   0.0118 0.3531 -0.0085 0.0321  False
# ---------------------------------------------------

# %%
#One-way ANOVA
groups = df1['FBS-classification'].unique()
group_data = [df1[df1['FBS-classification'] == group]['d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Streptococcaceae;g_Streptococcus'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Streptococcaceae;g_Streptococcus'], df1['FBS-classification'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 0.5502761387413243
# P-Value: 0.5786770042824216
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Db     NL   0.0268   0.62 -0.0416 0.0952  False
#     Db   P-Db  -0.0006 0.9998 -0.0875 0.0863  False
#     NL   P-Db  -0.0275  0.715 -0.1112 0.0562  False
# ---------------------------------------------------

# %%
#One-way ANOVA
groups = df1['HbA1C-classification'].unique()
group_data = [df1[df1['HbA1C-classification'] == group]['d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Streptococcaceae;g_Streptococcus'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Streptococcaceae;g_Streptococcus'], df1['HbA1C-classification'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 2.045697637090424
# P-Value: 0.13513040566805792
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Db     NL   0.0643 0.1462 -0.0166 0.1452  False
#     Db   P-Db  -0.0024 0.9962 -0.0719 0.0671  False
#     NL   P-Db  -0.0667 0.1777 -0.1554 0.0219  False
# ---------------------------------------------------

# %%
#One-way ANOVA
groups = df1['FBS-classification'].unique()
group_data = [df1[df1['FBS-classification'] == group]['d_Bacteria;p_Verrucomicrobiota;c_Verrucomicrobiae;o_Verrucomicrobiales;f_Akkermansiaceae;g_Akkermansia'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['d_Bacteria;p_Verrucomicrobiota;c_Verrucomicrobiae;o_Verrucomicrobiales;f_Akkermansiaceae;g_Akkermansia'], df1['FBS-classification'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 0.642040220907645
# P-Value: 0.5285589825698631
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Db     NL   0.0093  0.503 -0.0105 0.0292  False
#     Db   P-Db   0.0037 0.9342 -0.0215 0.0289  False
#     NL   P-Db  -0.0056 0.8455 -0.0299 0.0186  False
# ---------------------------------------------------

# %%
#One-way ANOVA
groups = df1['HbA1C-classification'].unique()
group_data = [df1[df1['HbA1C-classification'] == group]['d_Bacteria;p_Verrucomicrobiota;c_Verrucomicrobiae;o_Verrucomicrobiales;f_Akkermansiaceae;g_Akkermansia'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['d_Bacteria;p_Verrucomicrobiota;c_Verrucomicrobiae;o_Verrucomicrobiales;f_Akkermansiaceae;g_Akkermansia'], df1['HbA1C-classification'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 2.668299970834027
# P-Value: 0.07473708455630206
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Db     NL   0.0208 0.0905 -0.0025 0.0441  False
#     Db   P-Db  -0.0017 0.9785 -0.0217 0.0184  False
#     NL   P-Db  -0.0225 0.0967  -0.048 0.0031  False
# ---------------------------------------------------

# %%
#One-way ANOVA
groups = df1['FBS-classification'].unique()
group_data = [df1[df1['FBS-classification'] == group]['d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Atopobiaceae;g_Olsenella'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Atopobiaceae;g_Olsenella'], df1['FBS-classification'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 1.1991149347408654
# P-Value: 0.30612791269709855
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Db     NL  -0.0043  0.316 -0.0113 0.0027  False
#     Db   P-Db  -0.0041 0.5103  -0.013 0.0047  False
#     NL   P-Db   0.0001 0.9992 -0.0084 0.0087  False
# ---------------------------------------------------

# %%
#One-way ANOVA
groups = df1['HbA1C-classification'].unique()
group_data = [df1[df1['HbA1C-classification'] == group]['d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Atopobiaceae;g_Olsenella'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Atopobiaceae;g_Olsenella'], df1['HbA1C-classification'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 0.7278271746456261
# P-Value: 0.4857169470062085
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Db     NL  -0.0008 0.9691 -0.0093 0.0076  False
#     Db   P-Db  -0.0036 0.4574 -0.0109 0.0036  False
#     NL   P-Db  -0.0028 0.7513  -0.012 0.0064  False
# ---------------------------------------------------

# %%
#One-way ANOVA
groups = df1['FBS-classification'].unique()
group_data = [df1[df1['FBS-classification'] == group]['d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Coriobacteriaceae;g_Collinsella'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Coriobacteriaceae;g_Collinsella'], df1['FBS-classification'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 4.083482503975038
# P-Value: 0.019994583475928612
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     Db     NL  -0.0068 0.0468 -0.0135 -0.0001   True
#     Db   P-Db   0.0011 0.9451 -0.0074  0.0097  False
#     NL   P-Db   0.0079 0.0605 -0.0003  0.0161  False
# ----------------------------------------------------

# %%
#One-way ANOVA
groups = df1['HbA1C-classification'].unique()
group_data = [df1[df1['HbA1C-classification'] == group]['d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Coriobacteriaceae;g_Collinsella'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['d_Bacteria;p_Actinobacteriota;c_Coriobacteriia;o_Coriobacteriales;f_Coriobacteriaceae;g_Collinsella'], df1['HbA1C-classification'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 2.3622233163910282
# P-Value: 0.09990158632618457
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Db     NL  -0.0056 0.2356 -0.0138 0.0026  False
#     Db   P-Db  -0.0055 0.1532 -0.0126 0.0015  False
#     NL   P-Db   0.0001 0.9996 -0.0089 0.0091  False
# ---------------------------------------------------

# %%
#One-way ANOVA
groups = df1['FBS-classification'].unique()
group_data = [df1[df1['FBS-classification'] == group]['d_Bacteria;p_Bacteroidota;c_Bacteroidia;o_Bacteroidales;_;_'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['d_Bacteria;p_Bacteroidota;c_Bacteroidia;o_Bacteroidales;_;_'], df1['FBS-classification'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 0.497731132766666
# P-Value: 0.6095357877438983
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Db     NL  -0.0321 0.6599 -0.1198 0.0557  False
#     Db   P-Db  -0.0384 0.6916 -0.1498 0.0731  False
#     NL   P-Db  -0.0063 0.9893 -0.1136  0.101  False
# ---------------------------------------------------

# %%
#One-way ANOVA
groups = df1['HbA1C-classification'].unique()
group_data = [df1[df1['HbA1C-classification'] == group]['d_Bacteria;p_Bacteroidota;c_Bacteroidia;o_Bacteroidales;_;_'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['d_Bacteria;p_Bacteroidota;c_Bacteroidia;o_Bacteroidales;_;_'], df1['HbA1C-classification'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 1.337905764616254
# P-Value: 0.26745109595660677
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Db     NL  -0.0628 0.3282 -0.1672 0.0416  False
#     Db   P-Db   0.0113 0.9513 -0.0784 0.1011  False
#     NL   P-Db   0.0742 0.2755 -0.0403 0.1886  False
# ---------------------------------------------------

# %%
#One-way ANOVA
groups = df1['FBS-classification'].unique()
group_data = [df1[df1['FBS-classification'] == group]['d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Lactobacillaceae;g_Lactobacillus'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Lactobacillaceae;g_Lactobacillus'], df1['FBS-classification'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 5.277659111241362
# P-Value: 0.006763375139524148
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Db     NL   -0.052 0.1607 -0.1192 0.0151  False
#     Db   P-Db   0.0569  0.255 -0.0284 0.1423  False
#     NL   P-Db    0.109  0.006  0.0268 0.1911   True
# ---------------------------------------------------

# %%
#One-way ANOVA
groups = df1['HbA1C-classification'].unique()
group_data = [df1[df1['HbA1C-classification'] == group]['d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Lactobacillaceae;g_Lactobacillus'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['d_Bacteria;p_Firmicutes;c_Bacilli;o_Lactobacillales;f_Lactobacillaceae;g_Lactobacillus'], df1['HbA1C-classification'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 1.8674286521773078
# P-Value: 0.1603303425283001
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Db     NL  -0.0596 0.2109  -0.143 0.0239  False
#     Db   P-Db  -0.0423 0.3424 -0.1141 0.0294  False
#     NL   P-Db   0.0172 0.8952 -0.0743 0.1087  False
# ---------------------------------------------------

# %%
#One-way ANOVA
groups = df1['Group'].unique()
group_data = [df1[df1['Group'] == group]['Age'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['Age'], df1['Group'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 6.6760199413368
# P-Value: 0.00040010117224992763
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#     Ct    K-D  10.1667  0.001   3.3595 16.9739   True
#     Ct    P-D   3.7067  0.552  -3.6364 11.0497  False
#     Ct   UK-D      3.2 0.7381  -5.0098 11.4098  False
#    K-D    P-D    -6.46 0.0207 -12.1922 -0.7278   True
#    K-D   UK-D  -6.9667 0.0428 -13.7739 -0.1595   True
#    P-D   UK-D  -0.5067 0.9979  -7.8497  6.8364  False
# -----------------------------------------------------

# %%
#One-way ANOVA
groups = df1['Group'].unique()
group_data = [df1[df1['Group'] == group]['SBP'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['SBP'], df1['Group'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 1.8224141491508083
# P-Value: 0.148642754468798
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#     Ct    K-D   6.2583 0.6398  -7.6002 20.1169  False
#     Ct    P-D  -1.8667 0.9879 -16.8162 13.0828  False
#     Ct   UK-D   9.0667 0.4905  -7.6474 25.7807  False
#    K-D    P-D   -8.125 0.2697  -19.795   3.545  False
#    K-D   UK-D   2.8083 0.9515 -11.0502 16.6669  False
#    P-D   UK-D  10.9333 0.2294  -4.0162 25.8828  False
# -----------------------------------------------------

# %%
#One-way ANOVA
groups = df1['Group'].unique()
group_data = [df1[df1['Group'] == group]['DBP'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['DBP'], df1['Group'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 1.1802045023146557
# P-Value: 0.3217480947414644
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     Ct    K-D    0.925 0.9931 -8.0726  9.9226  False
#     Ct    P-D     1.48 0.9784 -8.2259 11.1859  False
#     Ct   UK-D      6.8 0.3616 -4.0515 17.6515  False
#    K-D    P-D    0.555 0.9975 -7.0216  8.1316  False
#    K-D   UK-D    5.875 0.3251 -3.1226 14.8726  False
#    P-D   UK-D     5.32 0.4813 -4.3859 15.0259  False
# ----------------------------------------------------

# %%
#One-way ANOVA
groups = df1['Group'].unique()
group_data = [df1[df1['Group'] == group]['Triglyceride'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['Triglyceride'], df1['Group'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 1.2975193654940713
# P-Value: 0.2801421699503183
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#     Ct    K-D  50.5827 0.2924  -24.0376  125.203  False
#     Ct    P-D  36.5187 0.6364  -43.9757 117.0131  False
#     Ct   UK-D   13.832 0.9779  -76.1635 103.8275  False
#    K-D    P-D  -14.064 0.9361  -76.8999  48.7719  False
#    K-D   UK-D -36.7507 0.5723  -111.371  37.8696  False
#    P-D   UK-D -22.6867 0.8817 -103.1811  57.8077  False
# -------------------------------------------------------

# %%
#One-way ANOVA
groups = df1['Group'].unique()
group_data = [df1[df1['Group'] == group]['Serum Creatinine'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['Serum Creatinine'], df1['Group'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 0.06988582077814685
# P-Value: 0.9758665687031355
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Ct    K-D  -0.0192 0.9899 -0.1825 0.1441  False
#     Ct    P-D  -0.0215 0.9887 -0.1976 0.1547  False
#     Ct   UK-D   0.0013    1.0 -0.1956 0.1983  False
#    K-D    P-D  -0.0023    1.0 -0.1398 0.1352  False
#    K-D   UK-D   0.0205 0.9877 -0.1428 0.1838  False
#    P-D   UK-D   0.0228 0.9865 -0.1534  0.199  False
# ---------------------------------------------------

# %%
#One-way ANOVA
groups = df1['Group'].unique()
group_data = [df1[df1['Group'] == group]['Cholesterol'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['Cholesterol'], df1['Group'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 0.9654181794223509
# P-Value: 0.41264155603983865
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#     Ct    K-D  26.0591 0.3826 -16.5091 68.6273  False
#     Ct    P-D  24.7045 0.4977 -21.2146 70.6237  False
#     Ct   UK-D  15.2513 0.8645 -36.0878 66.5905  False
#    K-D    P-D  -1.3546 0.9997 -37.2002 34.4911  False
#    K-D   UK-D -10.8077 0.9101  -53.376 31.7605  False
#    P-D   UK-D  -9.4532 0.9493 -55.3724  36.466  False
# -----------------------------------------------------

# %%
#One-way ANOVA
groups = df1['Group'].unique()
group_data = [df1[df1['Group'] == group]['Weight'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['Weight'], df1['Group'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 3.20033824912354
# P-Value: 0.027027064852972387
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#     Ct    K-D    9.855 0.0491   0.0276 19.6824   True
#     Ct    P-D    12.08 0.0189    1.479  22.681   True
#     Ct   UK-D   9.1467 0.1884  -2.7056 20.9989  False
#    K-D    P-D    2.225 0.8954  -6.0504 10.5004  False
#    K-D   UK-D  -0.7083 0.9976 -10.5357   9.119  False
#    P-D   UK-D  -2.9333 0.8872 -13.5343  7.6677  False
# -----------------------------------------------------

# %%
#One-way ANOVA
groups = df1['Group'].unique()
group_data = [df1[df1['Group'] == group]['Body Mass Index'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['Body Mass Index'], df1['Group'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 2.1941600678112025
# P-Value: 0.09410894826405211
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Ct    K-D   3.5075 0.0969 -0.4178 7.4329  False
#     Ct    P-D     3.72 0.1058 -0.5143 7.9544  False
#     Ct   UK-D   3.4674 0.2282 -1.2667 8.2016  False
#    K-D    P-D   0.2125 0.9983  -3.093 3.5179  False
#    K-D   UK-D  -0.0401    1.0 -3.9654 3.8853  False
#    P-D   UK-D  -0.2526 0.9986 -4.4869 3.9818  False
# ---------------------------------------------------

# %%
#One-way ANOVA
groups = df1['Group'].unique()
group_data = [df1[df1['Group'] == group]['Waist'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['Waist'], df1['Group'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 2.1254516692473575
# P-Value: 0.10243657278521086
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     Ct    K-D    7.544 0.0629 -0.2796 15.3676  False
#     Ct    P-D   5.6488 0.3034 -2.7907 14.0883  False
#     Ct   UK-D   5.6933 0.3956 -3.7423  15.129  False
#    K-D    P-D  -1.8952 0.8752 -8.4833  4.6929  False
#    K-D   UK-D  -1.8507 0.9257 -9.6743   5.973  False
#    P-D   UK-D   0.0445    1.0  -8.395  8.4841  False
# ----------------------------------------------------

# %%
#One-way ANOVA
groups = df1['Group'].unique()
group_data = [df1[df1['Group'] == group]['Hip'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['Hip'], df1['Group'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 2.233425280935173
# P-Value: 0.08965327175345456
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#     Ct    K-D   6.6067 0.1004  -0.8378 14.0512  False
#     Ct    P-D   6.8971 0.1183  -1.1334 14.9276  False
#     Ct   UK-D   3.6787 0.7072  -5.2997 12.6571  False
#    K-D    P-D   0.2904 0.9994  -5.9784  6.5592  False
#    K-D   UK-D   -2.928 0.7327 -10.3725  4.5165  False
#    P-D   UK-D  -3.2184 0.7212 -11.2489  4.8121  False
# -----------------------------------------------------

# %%
#One-way ANOVA
groups = df1['Group'].unique()
group_data = [df1[df1['Group'] == group]['Waist to Hip Ratio'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['Waist to Hip Ratio'], df1['Group'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 1.3465408281500193
# P-Value: 0.2642779674106422
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Ct    K-D   0.0112 0.9124 -0.0335 0.0559  False
#     Ct    P-D  -0.0114 0.9258 -0.0596 0.0368  False
#     Ct   UK-D   0.0217 0.7176 -0.0322 0.0756  False
#    K-D    P-D  -0.0226 0.3982 -0.0603  0.015  False
#    K-D   UK-D   0.0105 0.9274 -0.0342 0.0552  False
#    P-D   UK-D   0.0331 0.2808 -0.0151 0.0813  False
# ---------------------------------------------------

# %%
#One-way ANOVA
groups = df1['Group'].unique()
group_data = [df1[df1['Group'] == group]['HbA1C'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['HbA1C'], df1['Group'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 20.0698492521298
# P-Value: 4.544454536547352e-10
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     Ct    K-D   3.0542    0.0  1.7665  4.3418   True
#     Ct    P-D   0.5707 0.7054 -0.8183  1.9597  False
#     Ct   UK-D   2.6133 0.0002  1.0604  4.1663   True
#    K-D    P-D  -2.4835    0.0 -3.5678 -1.3992   True
#    K-D   UK-D  -0.4408 0.8069 -1.7285  0.8468  False
#    P-D   UK-D   2.0427 0.0012  0.6537  3.4317   True
# ----------------------------------------------------

# %%
#One-way ANOVA
groups = df1['Group'].unique()
group_data = [df1[df1['Group'] == group]['FBS'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['FBS'], df1['Group'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 14.445801167020617
# P-Value: 8.959140616888061e-08
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower    upper   reject
# ------------------------------------------------------
#     Ct    K-D    69.85    0.0  32.2771 107.4229   True
#     Ct    P-D     1.64 0.9996 -38.8906  42.1706  False
#     Ct   UK-D     50.0 0.0246   4.6854  95.3146   True
#    K-D    P-D   -68.21    0.0 -99.8492 -36.5708   True
#    K-D   UK-D   -19.85 0.5134 -57.4229  17.7229  False
#    P-D   UK-D    48.36 0.0126   7.8294  88.8906   True
# ------------------------------------------------------

# %%
#One-way ANOVA
groups = df1['Group'].unique()
group_data = [df1[df1['Group'] == group]['Insulin'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['Insulin'], df1['Group'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 1.338029788281599
# P-Value: 0.26697085454956426
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Ct    K-D   3.3543 0.2792 -1.5178 8.2263  False
#     Ct    P-D   3.7384 0.2519 -1.5172  8.994  False
#     Ct   UK-D   2.8833 0.5753 -2.9926 8.7593  False
#    K-D    P-D   0.3841 0.9948 -3.7185 4.4868  False
#    K-D   UK-D  -0.4709 0.9943  -5.343 4.4011  False
#    P-D   UK-D  -0.8551 0.9739 -6.1107 4.4005  False
# ---------------------------------------------------

# %%
#One-way ANOVA
groups = df1['Group'].unique()
group_data = [df1[df1['Group'] == group]['QUICKI'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['QUICKI'], df1['Group'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 5.7604213745605035
# P-Value: 0.0011844838113106303
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     Ct    K-D   -0.057 0.0008 -0.0945 -0.0194   True
#     Ct    P-D  -0.0328 0.1542 -0.0733  0.0077  False
#     Ct   UK-D  -0.0258 0.4464 -0.0711  0.0195  False
#    K-D    P-D   0.0242 0.1958 -0.0075  0.0558  False
#    K-D   UK-D   0.0312 0.1389 -0.0064  0.0687  False
#    P-D   UK-D    0.007  0.969 -0.0335  0.0475  False
# ----------------------------------------------------

# %%
#One-way ANOVA
groups = df1['Group'].unique()
group_data = [df1[df1['Group'] == group]['HOMA-IR'] for group in groups]
# Perform ANOVA
statistic, p_value = f_oneway(*group_data)
tukey_result = pairwise_tukeyhsd(df1['HOMA-IR'], df1['Group'])

# Output the results
print("ANOVA Results:")
print("F-Statistic:", statistic)
print("P-Value:", p_value)
print(tukey_result)
# Out:
# ANOVA Results:
# F-Statistic: 3.65969333992644
# P-Value: 0.015300869590737667
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     Ct    K-D   2.3202 0.0161  0.3225  4.318   True
#     Ct    P-D   0.8916 0.7009 -1.2634 3.0466  False
#     Ct   UK-D   1.3213 0.4809 -1.0881 3.7306  False
#    K-D    P-D  -1.4286 0.1249 -3.1108 0.2537  False
#    K-D   UK-D  -0.9989 0.5598 -2.9967 0.9988  False
#    P-D   UK-D   0.4296 0.9536 -1.7254 2.5847  False
# ---------------------------------------------------
